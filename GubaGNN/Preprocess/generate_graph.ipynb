# %%
import pickle
import pandas as pd
import networkx as nx

# %%
 my_string = 'dsgadg'
list1=[]
k= [list1.append(i) for i in my_string if i not in "aeiou"] 
print(k)
# Out:
# [None, None, None, None, None]

# %%
POST_PATH = '/home/afan/emotion_analysis/data/exact_match.p'
POST_DF_PATH = '/home/afan/emotion_analysis/data/processed_data/post_dict.p'

# %%
with open(POST_PATH, 'rb') as f:
    # {'id': index}
    post_dict = pickle.load(f)

# %%
post_dict
# Out:
# {920814525: 278048,
#  921089833: 280354,
#  937860017: 443914,
#  917665187: 246921,
#  906924017: 140243,
#  918446363: 254641,
#  945584744: 605869,
#  937243782: 437526,
#  899952472: 59032,
#  917936474: 249221,
#  899341127: 52324,
#  940347964: 470559,
#  934216128: 403987,
#  931928506: 383632,
#  931675265: 381622,
#  901564649: 77208,
#  919957419: 269526,
#  910712736: 185197,
#  914929292: 227856,
#  948533949: 638018,
#  913188989: 496114,
#  946178073: 613323,
#  899227596: 498945,
#  924783344: 317371,
#  912703749: 205380,
#  896019412: 7025,
#  938122633: 445989,
#  925443867: 324298,
#  912236888: 201218,
#  942275234: 496154,
#  922403604: 294487,
#  946436962: 615563,
#  912714945: 498838,
#  932637854: 390411,
#  943298771: 580586,
#  896499175: 14146,
#  909505079: 169412,
#  896443689: 12811,
#  922791156: 298131,
#  941263753: 479657,
#  931315678: 493037,
#  929600906: 362870,
#  940077235: 466837,
#  901558847: 77021,
#  899858743: 58139,
# ...

# %%
with open(POST_DF_PATH, 'rb') as f:
    post_df = pickle.load(f)

# %%
post_df = post_df
# Out:
# {'4f8d4e395621ccb6d5dc98c9e2f474a3': 0,
#  'e3cfbc7dfa6a191599e9bbe50681a0a0': 1,
#  'b4515ea4e862c95afe46eaaf2d720d96': 2,
#  'ac1b11e3b14c9a56be92522ff150ef7c': 3,
#  'e72c70a8f5faccd4336e0fb9a76e5765': 4,
#  'a7406befccdf98249dad9a8b1dadffc6': 5,
#  'de3a31b8af963abfc13b7b65777b621a': 6,
#  'ad76f8c1aa0a10a874a8ae5fd958b0ec': 7,
#  'ae73d849bca47b2861bcc6fe132ce595': 8,
#  '46d09a873c8cc4736aeda7dace062eb2': 9,
#  '9aaefccb8b4c09baffbcb5b20450e797': 10,
#  'ad125c6df6f1e0f8321da120829c45dc': 11,
#  '6b7d28622c99d44e1d634bbfeb19d237': 12,
#  '04628b33fea4923e801815459c27fe71': 13,
#  '3c203b00765a63ef7e3baaee4bd895ea': 14,
#  'c0f33947fde53369695c7cb87c9985c2': 15,
#  'c91606d6cb68a3439bc88467d95f8a30': 16,
#  '29a586d15b5c5037b1fbaa4cbd28fc68': 17,
#  '1cd1e2fde05d89cbdeaa708a7c24965a': 18,
#  '3f6a84f736cfb6c0c7f96fbf2ab10f57': 19,
#  'cf53527d5aa686fedf1db38f91b86919': 20,
#  '5841be4eb3df7f3f83333a198f1d055f': 21,
#  '53aa253445f9ba295cac049520b989c8': 22,
# ...
